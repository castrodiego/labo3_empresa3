# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
import random
from datetime import datetime

from pycaret.regression import *

pd.options.display.max_colwidth = 1000
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', None)

import warnings

warnings.filterwarnings('ignore')

pd.set_option('display.float_format', '{:.2f}'.format) #evitar notacion cientifica

# %%
####################################################
############# Setear segun cada maquina ############
os.chdir("C:/diego_tools/labo3/dataset")
####################################################

# %%
seed = 456456465

# %%
def error_rate(y, y_pred):
    dif_abs = sum(abs(y - y_pred))
    suma_real = sum(y)
    
    return round(100*dif_abs/suma_real,2)

# %%
df_sellout = pd.read_csv("emp3_sellout_product_train.csv")
df_sellout.head()
# Out:
#    product_id  periodo  imputado      tn  cust_request_tn  cust_request_qty  \
# 0       20001   201701         0  934.77           937.73            479.00
# 1       20001   201702         0  798.02           833.72            432.00
# 2       20001   201703         0 1303.36          1330.75            509.00
# 3       20001   201704         0 1069.96          1132.94            279.00
# 4       20001   201705         0 1502.20          1550.69            701.00
#
#    plan_precios_cuidados periodo_fecha  mes cat1         cat2     cat3  brand  \
# 0                   0.00    2017-01-01    1   HC  ROPA LAVADO  Liquido  ARIEL
# 1                   0.00    2017-02-01    2   HC  ROPA LAVADO  Liquido  ARIEL
# 2                   0.00    2017-03-01    3   HC  ROPA LAVADO  Liquido  ARIEL
# 3                   0.00    2017-04-01    4   HC  ROPA LAVADO  Liquido  ARIEL
# 4                   0.00    2017-05-01    5   HC  ROPA LAVADO  Liquido  ARIEL
#
#    sku_size  producto_estrella  temp_media  temp_max_media  temp_min_media  \
# 0   3000.00               1.00       25.65           30.40           20.90
# 1   3000.00               1.00       25.35           30.10           20.60
# 2   3000.00               1.00       22.45           26.90           18.00
# 3   3000.00               1.00       18.90           23.50           14.30
# 4   3000.00               1.00       15.90           19.50           12.30
#
#    IPC  promedio_mens_dolar_venta  catastrofe  tn_lag_1  tn_lag_2  tn_lag_3  \
# 0 1.60                      15.91       False       NaN       NaN       NaN
# 1 2.10                      15.59       False    934.77       NaN       NaN
# 2 2.40                      15.52       False    798.02    934.77       NaN
# 3 2.70                      15.36       False   1303.36    798.02    934.77
# 4 1.40                      15.72       False   1069.96   1303.36    798.02
#
#    tn_mas_2  tn_delta_1  tn_delta_2  tn_delta_3
# 0   1303.36         NaN         NaN         NaN
# 1   1069.96     -136.76         NaN         NaN
# 2   1502.20      505.34      368.59         NaN
# 3   1520.07     -233.40      271.95      135.19
# 4   1030.67      432.24      198.84      704.19

# %%
df_sellout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30825 entries, 0 to 30824
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   product_id                 30825 non-null  int64
#  1   periodo                    30825 non-null  int64
#  2   imputado                   30825 non-null  int64
#  3   tn                         30825 non-null  float64
#  4   cust_request_tn            30825 non-null  float64
#  5   cust_request_qty           30825 non-null  float64
#  6   plan_precios_cuidados      30825 non-null  float64
#  7   periodo_fecha              30825 non-null  object
#  8   mes                        30825 non-null  int64
#  9   cat1                       30825 non-null  object
#  10  cat2                       30825 non-null  object
#  11  cat3                       30825 non-null  object
#  12  brand                      30825 non-null  object
#  13  sku_size                   30825 non-null  float64
#  14  producto_estrella          30825 non-null  float64
#  15  temp_media                 30825 non-null  float64
#  16  temp_max_media             30825 non-null  float64
#  17  temp_min_media             30825 non-null  float64
#  18  IPC                        30825 non-null  float64
#  19  promedio_mens_dolar_venta  30825 non-null  float64
#  20  catastrofe                 30825 non-null  bool
#  21  tn_lag_1                   29592 non-null  float64
#  22  tn_lag_2                   28359 non-null  float64
#  23  tn_lag_3                   27126 non-null  float64
#  24  tn_mas_2                   30825 non-null  float64
#  25  tn_delta_1                 29592 non-null  float64
#  26  tn_delta_2                 28359 non-null  float64
#  27  tn_delta_3                 27126 non-null  float64
# dtypes: bool(1), float64(18), int64(4), object(5)
# memory usage: 6.4+ MB

# %%
df_train = df_sellout[df_sellout.periodo <= 201812]
df_holdout = df_sellout[df_sellout.periodo == 201902]

df_train.periodo.unique(),df_holdout.periodo.unique()
# Out:
# (array([201701, 201702, 201703, 201704, 201705, 201706, 201707, 201708,
#         201709, 201710, 201711, 201712, 201801, 201802, 201803, 201804,
#         201805, 201806, 201807, 201808, 201809, 201810, 201811, 201812],
#        dtype=int64),
#  array([201902], dtype=int64))

# %%
df_train_model = df_train.drop(columns=["periodo"])
df_holdout_model = df_holdout.drop(columns=["periodo"])

# %%
clf = setup(
            data = df_train_model,
            test_data=df_holdout_model,
            #fold_strategy = 'timeseries',
            data_split_stratify=False,
            data_split_shuffle=False,
            session_id=seed,
            target = 'tn_mas_2')


#Metricas
previous_metric_names = get_metrics().Name

for metric_name in previous_metric_names:
    remove_metric(metric_name)

add_metric('error_rate', 'Error Rate', error_rate, greater_is_better = False)

model = compare_models  (
                        sort="error_rate"
                        )
# Out:
# <style type="text/css">
# #T_5aafc_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5aafc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5aafc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5aafc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5aafc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5aafc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5aafc_row0_col1" class="data row0 col1" >456456465</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5aafc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5aafc_row1_col1" class="data row1 col1" >tn_mas_2</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5aafc_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_5aafc_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5aafc_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_5aafc_row3_col1" class="data row3 col1" >(30825, 27)</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5aafc_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_5aafc_row4_col1" class="data row4 col1" >(30825, 68)</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5aafc_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_5aafc_row5_col1" class="data row5 col1" >(29592, 68)</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5aafc_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_5aafc_row6_col1" class="data row6 col1" >(1233, 68)</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5aafc_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_5aafc_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5aafc_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_5aafc_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5aafc_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_5aafc_row9_col1" class="data row9 col1" >12.0%</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5aafc_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_5aafc_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5aafc_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_5aafc_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5aafc_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_5aafc_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5aafc_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_5aafc_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5aafc_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_5aafc_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5aafc_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_5aafc_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5aafc_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_5aafc_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5aafc_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_5aafc_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5aafc_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_5aafc_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5aafc_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_5aafc_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_5aafc_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_5aafc_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_5aafc_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_5aafc_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_5aafc_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_5aafc_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_5aafc_row22_col1" class="data row22 col1" >a105</td>
#     </tr>
#   </tbody>
# </table>
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                17:33:34
# Status     . . . . . . . . . . . . . . . . . .  Compiling Final Models
# Estimator  . . . . . . . . . . . . . . . . . .   K Neighbors Regressor
# <style type="text/css">
# #T_a2fd5 th {
#   text-align: left;
# }
# #T_a2fd5_row0_col0, #T_a2fd5_row0_col1, #T_a2fd5_row0_col2, #T_a2fd5_row1_col0, #T_a2fd5_row1_col1, #T_a2fd5_row1_col2, #T_a2fd5_row2_col0, #T_a2fd5_row2_col1, #T_a2fd5_row2_col2, #T_a2fd5_row3_col0, #T_a2fd5_row3_col1, #T_a2fd5_row3_col2, #T_a2fd5_row4_col0, #T_a2fd5_row4_col1, #T_a2fd5_row4_col2, #T_a2fd5_row5_col0, #T_a2fd5_row5_col1, #T_a2fd5_row5_col2, #T_a2fd5_row6_col0, #T_a2fd5_row6_col1, #T_a2fd5_row6_col2, #T_a2fd5_row7_col0, #T_a2fd5_row7_col1, #T_a2fd5_row7_col2, #T_a2fd5_row8_col0, #T_a2fd5_row8_col1, #T_a2fd5_row8_col2, #T_a2fd5_row9_col0, #T_a2fd5_row9_col1, #T_a2fd5_row9_col2, #T_a2fd5_row10_col0, #T_a2fd5_row10_col1, #T_a2fd5_row10_col2, #T_a2fd5_row11_col0, #T_a2fd5_row11_col1, #T_a2fd5_row11_col2, #T_a2fd5_row12_col0, #T_a2fd5_row12_col1, #T_a2fd5_row12_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_a2fd5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2fd5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a2fd5_level0_col1" class="col_heading level0 col1" >Error Rate</th>
#       <th id="T_a2fd5_level0_col2" class="col_heading level0 col2" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2fd5_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_a2fd5_row0_col0" class="data row0 col0" >K Neighbors Regressor</td>
#       <td id="T_a2fd5_row0_col1" class="data row0 col1" >81.4030</td>
#       <td id="T_a2fd5_row0_col2" class="data row0 col2" >0.4710</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_a2fd5_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_a2fd5_row1_col1" class="data row1 col1" >85.3070</td>
#       <td id="T_a2fd5_row1_col2" class="data row1 col2" >19.8050</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_a2fd5_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_a2fd5_row2_col1" class="data row2 col1" >111.5120</td>
#       <td id="T_a2fd5_row2_col2" class="data row2 col2" >0.3800</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row3" class="row_heading level0 row3" >huber</th>
#       <td id="T_a2fd5_row3_col0" class="data row3 col0" >Huber Regressor</td>
#       <td id="T_a2fd5_row3_col1" class="data row3 col1" >141.1630</td>
#       <td id="T_a2fd5_row3_col2" class="data row3 col2" >0.9280</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row4" class="row_heading level0 row4" >par</th>
#       <td id="T_a2fd5_row4_col0" class="data row4 col0" >Passive Aggressive Regressor</td>
#       <td id="T_a2fd5_row4_col1" class="data row4 col1" >208.8300</td>
#       <td id="T_a2fd5_row4_col2" class="data row4 col2" >0.2860</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row5" class="row_heading level0 row5" >omp</th>
#       <td id="T_a2fd5_row5_col0" class="data row5 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_a2fd5_row5_col1" class="data row5 col1" >456.3570</td>
#       <td id="T_a2fd5_row5_col2" class="data row5 col2" >0.1640</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row6" class="row_heading level0 row6" >lasso</th>
#       <td id="T_a2fd5_row6_col0" class="data row6 col0" >Lasso Regression</td>
#       <td id="T_a2fd5_row6_col1" class="data row6 col1" >553.0980</td>
#       <td id="T_a2fd5_row6_col2" class="data row6 col2" >0.8350</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row7" class="row_heading level0 row7" >en</th>
#       <td id="T_a2fd5_row7_col0" class="data row7 col0" >Elastic Net</td>
#       <td id="T_a2fd5_row7_col1" class="data row7 col1" >557.3390</td>
#       <td id="T_a2fd5_row7_col2" class="data row7 col2" >0.8560</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row8" class="row_heading level0 row8" >llar</th>
#       <td id="T_a2fd5_row8_col0" class="data row8 col0" >Lasso Least Angle Regression</td>
#       <td id="T_a2fd5_row8_col1" class="data row8 col1" >557.7340</td>
#       <td id="T_a2fd5_row8_col2" class="data row8 col2" >0.1780</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row9" class="row_heading level0 row9" >br</th>
#       <td id="T_a2fd5_row9_col0" class="data row9 col0" >Bayesian Ridge</td>
#       <td id="T_a2fd5_row9_col1" class="data row9 col1" >857.2550</td>
#       <td id="T_a2fd5_row9_col2" class="data row9 col2" >0.2910</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row10" class="row_heading level0 row10" >ridge</th>
#       <td id="T_a2fd5_row10_col0" class="data row10 col0" >Ridge Regression</td>
#       <td id="T_a2fd5_row10_col1" class="data row10 col1" >868.5810</td>
#       <td id="T_a2fd5_row10_col2" class="data row10 col2" >0.1810</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row11" class="row_heading level0 row11" >lr</th>
#       <td id="T_a2fd5_row11_col0" class="data row11 col0" >Linear Regression</td>
#       <td id="T_a2fd5_row11_col1" class="data row11 col1" >869.1790</td>
#       <td id="T_a2fd5_row11_col2" class="data row11 col2" >1.9460</td>
#     </tr>
#     <tr>
#       <th id="T_a2fd5_level0_row12" class="row_heading level0 row12" >lar</th>
#       <td id="T_a2fd5_row12_col0" class="data row12 col0" >Least Angle Regression</td>
#       <td id="T_a2fd5_row12_col1" class="data row12 col1" >99048978382752656.0000</td>
#       <td id="T_a2fd5_row12_col2" class="data row12 col2" >0.1940</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/81 [00:00<?, ?it/s]

# %%
plot_model(model, plot = 'feature')

# %%
#interpret_model(model)

# %%
prediction_holdout = predict_model(model)

prediction_holdout

# %%
prediction_holdout[prediction_holdout.product_id==20001]

# %%
final_best = finalize_model(model)
