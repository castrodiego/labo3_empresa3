# %%
import pandas as pd
import os

# %%
os.chdir("C:/Users/herna/OneDrive/Documentos/Labo_3/labo3_empresa3_repo/datasets")

# %%
#Lea el Dataset base
data = "emp3_sellout_base_period_product.csv"
df = pd.read_csv(data)
df.head()
# Out:
#    periodo periodo_fecha  product_id          tn  cust_request_qty  \
# 0   201701    2017-01-01       20001   934.77222               479
# 1   201701    2017-01-01       20002   550.15707               391
# 2   201701    2017-01-01       20003  1063.45835               438
# 3   201701    2017-01-01       20004   555.91614               339
# 4   201701    2017-01-01       20005   494.27011               249
#
#    cust_request_tn  plan_precios_cuidados   cat1         cat2      cat3  ...  \
# 0        937.72717                      0     HC  ROPA LAVADO   Liquido  ...
# 1        555.18654                      0     HC  ROPA LAVADO   Liquido  ...
# 2       1067.81543                      0  FOODS     ADEREZOS  Mayonesa  ...
# 3        569.37394                      0  FOODS     ADEREZOS  Mayonesa  ...
# 4        494.60084                      0  FOODS     ADEREZOS  Mayonesa  ...
#
#    cat3_delta_lag_26  cat3_delta_lag_27  cat3_delta_lag_28  cat3_delta_lag_29  \
# ...

# %%
# Como son 36 periodos que podemos usar para entrenar + validacion, use esa cantidad de lags teniendo en cuenta que LighGBM puede trabajar con valores nulos
# Aplico los lags + delta lags para product_id
num_lags = 36

# Lags para product_id
for i in range(1, num_lags + 1):
    df[f'product_id_lag_{i}'] = df.groupby('product_id')['tn'].shift(i)

# Delta lags para product_id
for i in range(1, num_lags):
    df[f'product_id_delta_lag_{i}'] = df[f'product_id_lag_{i}'] - df[f'product_id_lag_{i + 1}']

# %%
# Aplico los lags + delta lags para cat1
num_lags = 36

# Lags para cat1
for i in range(1, num_lags + 1):
    df[f'cat1_lag_{i}'] = df.groupby('cat1')['tn'].shift(i)

# Delta lags para cat1
for i in range(1, num_lags):
    df[f'cat1_delta_lag_{i}'] = df[f'cat1_lag_{i}'] - df[f'cat1_lag_{i + 1}']
# Out:
# C:\Users\herna\AppData\Local\Temp\ipykernel_24780\1108444726.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cat1_lag_{i}'] = df.groupby('cat1')['tn'].shift(i)
# C:\Users\herna\AppData\Local\Temp\ipykernel_24780\1108444726.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cat1_lag_{i}'] = df.groupby('cat1')['tn'].shift(i)
# ...

# %%
# Aplico los lags + delta lags para cat2
num_lags = 36

# Lags para cat2
for i in range(1, num_lags + 1):
    df[f'cat2_lag_{i}'] = df.groupby('cat2')['tn'].shift(i)

# Delta lags para cat2
for i in range(1, num_lags):
    df[f'cat2_delta_lag_{i}'] = df[f'cat2_lag_{i}'] - df[f'cat2_lag_{i + 1}']
# Out:
# C:\Users\herna\AppData\Local\Temp\ipykernel_24780\2685364707.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cat2_lag_{i}'] = df.groupby('cat2')['tn'].shift(i)
# C:\Users\herna\AppData\Local\Temp\ipykernel_24780\2685364707.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cat2_lag_{i}'] = df.groupby('cat2')['tn'].shift(i)
# ...

# %%
# Aplico los lags + delta lags para cat3
num_lags = 36

# Lags para cat3
for i in range(1, num_lags + 1):
    df[f'cat3_lag_{i}'] = df.groupby('cat3')['tn'].shift(i)

# Delta lags para cat3
for i in range(1, num_lags):
    df[f'cat3_delta_lag_{i}'] = df[f'cat3_lag_{i}'] - df[f'cat3_lag_{i + 1}']
# Out:
# C:\Users\herna\AppData\Local\Temp\ipykernel_24780\517213934.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cat3_lag_{i}'] = df.groupby('cat3')['tn'].shift(i)
# C:\Users\herna\AppData\Local\Temp\ipykernel_24780\517213934.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[f'cat3_lag_{i}'] = df.groupby('cat3')['tn'].shift(i)
# ...

# %%
df
# Out:
#        periodo periodo_fecha  product_id          tn  cust_request_qty  \
# 0       201701    2017-01-01       20001   934.77222               479
# 1       201701    2017-01-01       20002   550.15707               391
# 2       201701    2017-01-01       20003  1063.45835               438
# 3       201701    2017-01-01       20004   555.91614               339
# 4       201701    2017-01-01       20005   494.27011               249
# ...        ...           ...         ...         ...               ...
# 31238   201912    2019-12-01       21265     0.05007                 5
# 31239   201912    2019-12-01       21266     0.05121                 6
# 31240   201912    2019-12-01       21267     0.01569                 4
# 31241   201912    2019-12-01       21271     0.00298                 4
# 31242   201912    2019-12-01       21276     0.00892                 4
#
#        cust_request_tn  plan_precios_cuidados   cat1         cat2  \
# ...

# %%
# Exportar el DataFrame a un archivo CSV
df.to_csv("emp3_sellout_lags_deltalags_product_categorias.csv", index=False)
