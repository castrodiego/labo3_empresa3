# %%
import os
import lightgbm as lgb
import pandas as pd
import warnings
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
import winsound
import datetime
import optuna
import random

pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_columns', None)

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
####################################################
############# Setear segun cada maquina ############
#os.chdir("C:/Users/herna/labo3_empresa3_repo/datasets")
os.chdir("C:/diego_tools/labo3/dataset")
####################################################

# %%
arch_sellout_train = "emp3_sellout_product_train.csv"
arch_min_max_prod = "emp3_min_max_prod.csv"
arch_mean_std_prod = "emp3_mean_std_prod.csv"
arch_prod_ids_prediccion = "productos_a_predecir.csv"
arch_predicciones_full = "emp3_lightgbm_prediccion_full.csv"
arch_predicciones_simple = "emp3_lightgbm_prediccion.csv"

# %%
tipos_transf = ['sin_transformacion', 'normalizacion', 'estandarizacion']
GLOBAL_TRANSF = tipos_transf[1]
CANT_ITERACIONES_OPT_BAY = 30
CANT_SEMILLAS = 20

#MAX_BIN_PARAM=255
MAX_BIN_PARAM=1023

GLOBAL_PRODUCT_IDS = pd.DataFrame() #aca solamente se define, se setea mas abajo

# %%
# Marco en train, holdout y descartar para considerarlo en las transformaciones
periodo_inicio=201701 #inclusive
train_periodo_limite = 201810 #inclusive
validate_periodo = 201812
train_all_periodo_limite = 201812 #inclusive
holdout_periodo = 201902

# %%
########### NORMALIZACION
def normalizar_valor(valor,minimo,maximo):
    if np.isnan(minimo):
        return valor #si no hay minimo, devuelvo valor original (no tener minimo significa que no habia datos en train)
    else:
        if (maximo-minimo)==0: 
            return 0
        else:
            return (valor - minimo) / (maximo-minimo)

        
def desnormalizar_valor(valor,minimo,maximo):
    if np.isnan(minimo):
        return valor #si no hay minimo, devuelvo valor original (no tener minimo significa que no habia datos en train)
    else:
        return (valor * (maximo-minimo)) + minimo

def normalizar_tn(df_param):
    #Calculo min max solamente sobre train (para evitar data leakage)
    df_train = df_param[(df_param.periodo<=train_periodo_limite) & (df_param.periodo >= periodo_inicio)]
    df_train = df_train[["product_id","tn"]]
    
    #Calculo min max por producto y lo guardo para poder revertir posteriormente
    df_min_max_prod = df_train.groupby('product_id')['tn'].agg(['max', 'min']).reset_index()
    df_min_max_prod = df_min_max_prod.rename(columns={"min":"valor_1","max":"valor_2"})
    df_min_max_prod.to_csv(arch_min_max_prod, index=False)
        
    df_ret = df_param.merge(df_min_max_prod,how="left",on="product_id") #puede haber productos que no aparezcan, por eso left
    
    # Selecciono columnas a normalizar
    
    # Me guardo la original para comparar
    df_ret["tn_original"]=df_ret.tn
    
    # Dropeo algunas (para evitar ruido)
    cols_remover = ["cust_request_tn","dif_cust_request_tn","cust_request_qty"]
    cols_remover.extend([col for col in df_ret.columns if "cat1_" in col])
    cols_remover.extend([col for col in df_ret.columns if "cat2_" in col])
    cols_remover.extend([col for col in df_ret.columns if "cat3_" in col])
        
    df_ret = df_ret.drop(columns=cols_remover)  
    
    # Normalizo tn, lags y deltas
    lag_cols = [col for col in df_ret.columns if "lag" in col]
    delta_cols = [col for col in df_ret.columns if "delta" in col]
    cols_norm = ["tn","tn_mas_2"]
    cols_norm.extend(lag_cols)
    cols_norm.extend(delta_cols)
                    
    for col_norm in cols_norm:
        df_ret[col_norm] =df_ret.apply(lambda row: normalizar_valor(row[col_norm],row["valor_1"],row["valor_2"]),axis=1)
    
    return df_ret

############# ESTANDARIZACION
def estandarizar_valor(valor,media,desvio):
    if np.isnan(media):
        return valor #si no hay media, devuelvo valor original (no tener media significa que no habia datos en train)
    else:
        if desvio==0: 
            return 0
        else:
            return (valor - media) / desvio

def desestandarizar_valor(valor,media,desvio):
    if np.isnan(media):
        return valor #si no hay media, devuelvo valor original (no tener media significa que no habia datos en train)
    else:
        return (valor * desvio) + media
    
def estandarizar_tn(df_param):
    #Calculo min max solamente sobre train (para evitar data leakage)
    df_train = df_param[(df_param.periodo<=train_periodo_limite) & (df_param.periodo >= periodo_inicio)]
    df_train = df_train[["product_id","tn"]]
    
    #Calculo media y desvio por producto y lo guardo para poder revertir posteriormente
    df_mean_std_prod = df_train.groupby('product_id')['tn'].agg(['mean', lambda x: np.std(x,ddof=0)]).reset_index() #se usa ddof=0 para evitar NaN cuando hay un solo producto
    df_mean_std_prod.columns = ["product_id",'valor_1', 'valor_2']
    df_mean_std_prod.to_csv(arch_mean_std_prod, index=False)
        
    df_ret = df_param.merge(df_mean_std_prod,how="left",on="product_id")
    
    # Selecciono columnas a estandarizar
    
    # Me guardo la original para comparar
    df_ret["tn_original"]=df_ret.tn
    
    # Dropeo algunas (para evitar ruido)
    cols_remover = ["cust_request_tn","dif_cust_request_tn","cust_request_qty"]
    cols_remover.extend([col for col in df_ret.columns if "cat1_" in col])
    cols_remover.extend([col for col in df_ret.columns if "cat2_" in col])
    cols_remover.extend([col for col in df_ret.columns if "cat3_" in col])
        
    df_ret = df_ret.drop(columns=cols_remover)  
    
    # Estandarizo tn, lags y deltas
    lag_cols = [col for col in df_ret.columns if "lag" in col]
    delta_cols = [col for col in df_ret.columns if "delta" in col]
    cols_norm = ["tn","tn_mas_2"]
    cols_norm.extend(lag_cols)
    cols_norm.extend(delta_cols)
                    
    for col_norm in cols_norm:
        df_ret[col_norm] =df_ret.apply(lambda row: estandarizar_valor(row[col_norm],row["valor_1"],row["valor_2"]),axis=1)
    
    return df_ret

################### TRANSFORMACION    
def transformar_valor(valor,var1,var2):
    if GLOBAL_TRANSF=="normalizacion":
        return normalizar_valor(valor,var1,var2)
    elif GLOBAL_TRANSF=="estandarizacion":
        return estandarizar_valor(valor,var1,var2)
    else:
        return valor

def destransformar_valor(valor,var1,var2):
    if GLOBAL_TRANSF=="normalizacion":
        return desnormalizar_valor(valor,var1,var2)
    elif GLOBAL_TRANSF=="estandarizacion":
        return desestandarizar_valor(valor,var1,var2)
    else:
        return valor

def graficar_ejemplo_transformacion(df_param):
    df_param = df_param[df_param.product_id==20001]
    
    plt.plot(df_param.tn_original)
    plt.title("Original")
    plt.show()
    
    plt.plot(df_param.tn)
    plt.title("Transformado")
    plt.show()

# %%
def semillerio(lgbtrain_all, lgb_params, best_iteration, X_holdout, y_holdout):
    er_holdout_list = []
    y_pred_holdout_list = []

    for i in range(0,CANT_SEMILLAS):
        seed = random.randint(1,99999999999999)
        lgb_params_new = {**lgb_params, **{"seed":seed}}

        final_model = lgb.train(lgb_params_new, lgbtrain_all, num_boost_round=best_iteration)

        y_pred_holdout = final_model.predict(X_holdout)
        er_holdout = error_rate(y_holdout,y_pred_holdout)

        y_pred_holdout_list.append(y_pred_holdout)
        er_holdout_list.append(er_holdout)

    #min(er_holdout_list),max(er_holdout_list),round(np.mean(er_holdout_list),2),round(np.median(er_holdout_list),2), round(np.std(er_holdout_list),2)
    y_pred_holdout_semillerio = np.sum(y_pred_holdout_list,axis=0)/CANT_SEMILLAS
    er_holdout_semillerio = error_rate(y_holdout,y_pred_holdout_semillerio)
    return er_holdout_semillerio

# %%
############ DEFINO Vector Global de Productos #################
def actualizar_global_prods(y_vector):
    # Ademas del id y los valores para "destransformar", se deja el tn original porque la destransformacion puede no ser
    # precisa para productos que no estaban en train
    GLOBAL_PRODUCT_IDS = pd.DataFrame(data={"product_id":X_holdout.product_id, "tn_orig":np.array(y_vector)})
    GLOBAL_PRODUCT_IDS = GLOBAL_PRODUCT_IDS.merge(df_prod_val1_val2,how="left",on="product_id")
    GLOBAL_PRODUCT_IDS = GLOBAL_PRODUCT_IDS.sort_values(by="product_id",ascending=True)
    
    return GLOBAL_PRODUCT_IDS

# %%
def error_rate(y, y_pred):
    y_pred = np.array(y_pred)
    
    #Solamente destransformo la prediccion (para el y tomo el original de la columna tn_orig)
    df_calculo = GLOBAL_PRODUCT_IDS.copy()
    df_calculo["y_pred"] = y_pred
    df_calculo["y_pred_destransformado"]=df_calculo.apply(lambda row: destransformar_valor(row["y_pred"],row["valor_1"],row["valor_2"]),axis=1)

    y = df_calculo.tn_orig
    y_pred = df_calculo.y_pred_destransformado
    
    #Las predicciones negativas se convierten a 0
    y_pred = np.maximum(y_pred, 0)
    
    dif_abs = sum(abs(y - y_pred))
    suma_real = sum(y)
    return round(100*dif_abs/suma_real,2)

def lgbm_error_rate(preds, train_data):
    labels = train_data.get_label()
    ret_val = error_rate(labels,preds)
    return 'ER', ret_val, False

# %%
def destransformar_vector(y_vector):
    df_calculo = GLOBAL_PRODUCT_IDS.copy()
    df_calculo["y"] = y_vector
    df_calculo["y_destransformado"]=df_calculo.apply(lambda row: destransformar_valor(row["y"],row["valor_1"],row["valor_2"]),axis=1)

    return df_calculo.y_destransformado

# %%
def plot_lgb_importances(model, plot=False, num=10):
    gain = model.feature_importance('gain')
    feat_imp = pd.DataFrame({'feature': model.feature_name(),
                             'split': model.feature_importance('split'),
                             'gain': 100 * gain / gain.sum()}).sort_values('gain', ascending=False)
    if plot:
        plt.figure(figsize=(10, 10))
        sns.set(font_scale=1)
        sns.barplot(x="gain", y="feature", data=feat_imp[0:25])
        plt.title('feature')
        plt.tight_layout()
        plt.show(block=True)
    else:
        print(feat_imp.head(num))
    return feat_imp

# %%
##############################################

# %%
df_sellout = pd.read_csv(arch_sellout_train)

# %%
df_sellout.head()
# Out:
#    product_id  periodo  imputado     tn  cust_request_tn  cust_request_qty  \
# 0       20001   201701         0 934.77           937.73            479.00
# 1       20002   201701         0 550.16           555.19            391.00
# 2       20009   201701         0 378.08           380.53            429.00
# 3       20015   201701         0 304.25           307.99            374.00
# 4       20026   201701         0 184.40           185.11            307.00
#
#    plan_precios_cuidados periodo_fecha  mes  meses_historia cat1         cat2  \
# 0                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
# 1                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
# 2                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
# 3                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
# 4                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
#
#       cat3    brand  sku_size  producto_estrella  temp_media  temp_max_media  \
# 0  Liquido    ARIEL   3000.00               1.00       25.65           30.40
# 1  Liquido  LIMPIEX   3000.00               1.00       25.65           30.40
# 2  Liquido   ROPEX1   3000.00               1.00       25.65           30.40
# 3  Liquido   ROPEX1    800.00               0.00       25.65           30.40
# 4  Liquido  LIMPIEX    800.00               0.00       25.65           30.40
#
#    temp_min_media  IPC  promedio_mens_dolar_venta  catastrofe  \
# 0           20.90 1.60                      15.91       False
# 1           20.90 1.60                      15.91       False
# 2           20.90 1.60                      15.91       False
# 3           20.90 1.60                      15.91       False
# 4           20.90 1.60                      15.91       False
#
#    dif_cust_request_tn  dif_cust_request_tn_porc  tn_lag_1  tn_lag_2  \
# 0                 2.95                      0.32       NaN       NaN
# 1                 5.03                      0.91       NaN       NaN
# 2                 2.45                      0.64       NaN       NaN
# 3                 3.74                      1.22       NaN       NaN
# 4                 0.71                      0.38       NaN       NaN
#
#    tn_lag_3  tn_lag_4  tn_lag_5  tn_lag_6  tn_lag_7  tn_lag_8  tn_lag_9  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    tn_lag_10  tn_lag_11  tn_lag_12  tn_lag_13  tn_lag_14  tn_lag_15  tn_mas_2  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN   1303.36
# 1        NaN        NaN        NaN        NaN        NaN        NaN    834.74
# 2        NaN        NaN        NaN        NaN        NaN        NaN    456.07
# 3        NaN        NaN        NaN        NaN        NaN        NaN    462.48
# 4        NaN        NaN        NaN        NaN        NaN        NaN    259.71
#
#    tn_delta_1  tn_delta_2  tn_delta_3  tn_delta_4  tn_delta_5  tn_delta_6  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    tn_delta_7  tn_delta_8  tn_delta_9  tn_delta_10  tn_delta_11  tn_delta_12  \
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN
#
#    tn_delta_13  tn_delta_14  tn_delta_15  cat1_tn  cat1_tn_lag_1  \
# 0          NaN          NaN          NaN 20304.29            NaN
# 1          NaN          NaN          NaN 20304.29            NaN
# 2          NaN          NaN          NaN 20304.29            NaN
# 3          NaN          NaN          NaN 20304.29            NaN
# 4          NaN          NaN          NaN 20304.29            NaN
#
#    cat1_tn_delta_1  cat1_tn_lag_2  cat1_tn_delta_2  cat1_tn_lag_3  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat1_tn_delta_3  cat1_tn_lag_4  cat1_tn_delta_4  cat1_tn_lag_5  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat1_tn_delta_5  cat1_tn_lag_6  cat1_tn_delta_6  cat1_tn_lag_7  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat1_tn_delta_7  cat1_tn_lag_8  cat1_tn_delta_8  cat1_tn_lag_9  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat1_tn_delta_9  cat1_tn_lag_10  cat1_tn_delta_10  cat1_tn_lag_11  \
# 0              NaN             NaN               NaN             NaN
# 1              NaN             NaN               NaN             NaN
# 2              NaN             NaN               NaN             NaN
# 3              NaN             NaN               NaN             NaN
# 4              NaN             NaN               NaN             NaN
#
#    cat1_tn_delta_11  cat1_tn_lag_12  cat1_tn_delta_12  cat1_tn_lag_13  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat1_tn_delta_13  cat1_tn_lag_14  cat1_tn_delta_14  cat1_tn_lag_15  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat1_tn_delta_15  cat2_tn  cat2_tn_lag_1  cat2_tn_delta_1  cat2_tn_lag_2  \
# 0               NaN 11153.30            NaN              NaN            NaN
# 1               NaN 11153.30            NaN              NaN            NaN
# 2               NaN 11153.30            NaN              NaN            NaN
# 3               NaN 11153.30            NaN              NaN            NaN
# 4               NaN 11153.30            NaN              NaN            NaN
#
#    cat2_tn_delta_2  cat2_tn_lag_3  cat2_tn_delta_3  cat2_tn_lag_4  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat2_tn_delta_4  cat2_tn_lag_5  cat2_tn_delta_5  cat2_tn_lag_6  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat2_tn_delta_6  cat2_tn_lag_7  cat2_tn_delta_7  cat2_tn_lag_8  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat2_tn_delta_8  cat2_tn_lag_9  cat2_tn_delta_9  cat2_tn_lag_10  \
# 0              NaN            NaN              NaN             NaN
# 1              NaN            NaN              NaN             NaN
# 2              NaN            NaN              NaN             NaN
# 3              NaN            NaN              NaN             NaN
# 4              NaN            NaN              NaN             NaN
#
#    cat2_tn_delta_10  cat2_tn_lag_11  cat2_tn_delta_11  cat2_tn_lag_12  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat2_tn_delta_12  cat2_tn_lag_13  cat2_tn_delta_13  cat2_tn_lag_14  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat2_tn_delta_14  cat2_tn_lag_15  cat2_tn_delta_15  cat3_tn  cat3_tn_lag_1  \
# 0               NaN             NaN               NaN  3871.39            NaN
# 1               NaN             NaN               NaN  3871.39            NaN
# 2               NaN             NaN               NaN  3871.39            NaN
# 3               NaN             NaN               NaN  3871.39            NaN
# 4               NaN             NaN               NaN  3871.39            NaN
#
#    cat3_tn_delta_1  cat3_tn_lag_2  cat3_tn_delta_2  cat3_tn_lag_3  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat3_tn_delta_3  cat3_tn_lag_4  cat3_tn_delta_4  cat3_tn_lag_5  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat3_tn_delta_5  cat3_tn_lag_6  cat3_tn_delta_6  cat3_tn_lag_7  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat3_tn_delta_7  cat3_tn_lag_8  cat3_tn_delta_8  cat3_tn_lag_9  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat3_tn_delta_9  cat3_tn_lag_10  cat3_tn_delta_10  cat3_tn_lag_11  \
# 0              NaN             NaN               NaN             NaN
# 1              NaN             NaN               NaN             NaN
# 2              NaN             NaN               NaN             NaN
# 3              NaN             NaN               NaN             NaN
# 4              NaN             NaN               NaN             NaN
#
#    cat3_tn_delta_11  cat3_tn_lag_12  cat3_tn_delta_12  cat3_tn_lag_13  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat3_tn_delta_13  cat3_tn_lag_14  cat3_tn_delta_14  cat3_tn_lag_15  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat3_tn_delta_15
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df_sellout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23173 entries, 0 to 23172
# Columns: 148 entries, product_id to cat3_tn_delta_15
# dtypes: bool(1), float64(137), int64(5), object(5)
# memory usage: 26.0+ MB

# %%
df_sellout.isna().sum()
# Out:
# product_id              0
# periodo                 0
# imputado                0
# tn                      0
# cust_request_tn         0
#                     ...
# cat3_tn_delta_13    11508
# cat3_tn_lag_14      12456
# cat3_tn_delta_14    12456
# cat3_tn_lag_15      13397
# cat3_tn_delta_15    13397
# Length: 148, dtype: int64

# %%
df_prods_prediccion=pd.read_csv(arch_prod_ids_prediccion)
df_prods_prediccion.head()
# Out:
#    product_id
# 0       20480
# 1       20481
# 2       20482
# 3       20483
# 4       20484

# %%
df_prods_prediccion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 868 entries, 0 to 867
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  868 non-null    int64
# dtypes: int64(1)
# memory usage: 6.9 KB

# %%
# Antes de transformar, se guardan los y_validate y holdout originales (se van a usar en el vector global)
# Esto se debe a que la "destransformacion" no siempre es perfecta, considerando productos que no estuvieron en train
df_sellout_validate_orig = df_sellout[(df_sellout.product_id.isin(df_prods_prediccion.product_id)) & (df_sellout.periodo==validate_periodo)]
df_sellout_validate_orig = df_sellout_validate_orig.sort_values(by="product_id",ascending=True)
y_validate_orig = df_sellout_validate_orig.tn_mas_2
print(len(y_validate_orig))

df_sellout_holdout_orig = df_sellout[(df_sellout.product_id.isin(df_prods_prediccion.product_id)) & (df_sellout.periodo==holdout_periodo)]
df_sellout_holdout_orig = df_sellout_holdout_orig.sort_values(by="product_id",ascending=True)
y_holdout_orig = df_sellout_holdout_orig.tn_mas_2
print(len(y_holdout_orig))
# Out:
# 868
# 868

# %%
if GLOBAL_TRANSF == "sin_transformacion":
    print("Sin Transformacion")
     # Dropeo algunas (para evitar ruido)
    cols_remover = ["cust_request_tn","dif_cust_request_tn","cust_request_qty"]
    cols_remover.extend([col for col in df_sellout.columns if "cat1_" in col])
    cols_remover.extend([col for col in df_sellout.columns if "cat2_" in col])
    cols_remover.extend([col for col in df_sellout.columns if "cat3_" in col])
        
    df_sellout_transf = df_sellout.drop(columns=cols_remover)  
        
    df_prod_val1_val2 = pd.DataFrame(data={"product_id":df_sellout.product_id.unique()})
    df_prod_val1_val2["valor_1"]=0
    df_prod_val1_val2["valor_2"]=0
    
elif GLOBAL_TRANSF == "normalizacion":
    print("Normalizacion")
    print(len(df_sellout))
    df_sellout_transf = normalizar_tn(df_sellout)
    print(len(df_sellout_transf))

    graficar_ejemplo_transformacion(df_sellout_transf)
    df_sellout_transf = df_sellout_transf.drop(columns=["tn_original","valor_1","valor_2"])
    
    df_prod_val1_val2 = pd.read_csv(arch_min_max_prod)

elif GLOBAL_TRANSF == "estandarizacion":
    print("Estandarizacion")
    df_sellout_transf = estandarizar_tn(df_sellout)
    graficar_ejemplo_transformacion(df_sellout_transf)
    df_sellout_transf = df_sellout_transf.drop(columns=["tn_original","valor_1","valor_2"])
   
    df_prod_val1_val2 = pd.read_csv(arch_mean_std_prod)
    
df_sellout_transf.head()
# Out:
# Normalizacion
# 23173
# 23173
#    product_id  periodo  imputado   tn  cust_request_tn  cust_request_qty  \
# 0       20001   201701         0 0.09           937.73            479.00
# 1       20002   201701         0 0.05           555.19            391.00
# 2       20009   201701         0 0.39           380.53            429.00
# 3       20015   201701         0 0.08           307.99            374.00
# 4       20026   201701         0 0.14           185.11            307.00
#
#    plan_precios_cuidados periodo_fecha  mes  meses_historia cat1         cat2  \
# 0                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
# 1                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
# 2                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
# 3                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
# 4                   0.00    2017-01-01    1               0   HC  ROPA LAVADO
#
#       cat3    brand  sku_size  producto_estrella  temp_media  temp_max_media  \
# 0  Liquido    ARIEL   3000.00               1.00       25.65           30.40
# 1  Liquido  LIMPIEX   3000.00               1.00       25.65           30.40
# 2  Liquido   ROPEX1   3000.00               1.00       25.65           30.40
# 3  Liquido   ROPEX1    800.00               0.00       25.65           30.40
# 4  Liquido  LIMPIEX    800.00               0.00       25.65           30.40
#
#    temp_min_media  IPC  promedio_mens_dolar_venta  catastrofe  \
# 0           20.90 1.60                      15.91       False
# 1           20.90 1.60                      15.91       False
# 2           20.90 1.60                      15.91       False
# 3           20.90 1.60                      15.91       False
# 4           20.90 1.60                      15.91       False
#
#    dif_cust_request_tn  dif_cust_request_tn_porc  tn_lag_1  tn_lag_2  \
# 0                 2.95                      0.32       NaN       NaN
# 1                 5.03                      0.91       NaN       NaN
# 2                 2.45                      0.64       NaN       NaN
# 3                 3.74                      1.22       NaN       NaN
# 4                 0.71                      0.38       NaN       NaN
#
#    tn_lag_3  tn_lag_4  tn_lag_5  tn_lag_6  tn_lag_7  tn_lag_8  tn_lag_9  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    tn_lag_10  tn_lag_11  tn_lag_12  tn_lag_13  tn_lag_14  tn_lag_15  tn_mas_2  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN      0.34
# 1        NaN        NaN        NaN        NaN        NaN        NaN      0.38
# 2        NaN        NaN        NaN        NaN        NaN        NaN      0.61
# 3        NaN        NaN        NaN        NaN        NaN        NaN      0.61
# 4        NaN        NaN        NaN        NaN        NaN        NaN      0.44
#
#    tn_delta_1  tn_delta_2  tn_delta_3  tn_delta_4  tn_delta_5  tn_delta_6  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    tn_delta_7  tn_delta_8  tn_delta_9  tn_delta_10  tn_delta_11  tn_delta_12  \
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN
#
#    tn_delta_13  tn_delta_14  tn_delta_15  cat1_tn  cat1_tn_lag_1  \
# 0          NaN          NaN          NaN 20304.29            NaN
# 1          NaN          NaN          NaN 20304.29            NaN
# 2          NaN          NaN          NaN 20304.29            NaN
# 3          NaN          NaN          NaN 20304.29            NaN
# 4          NaN          NaN          NaN 20304.29            NaN
#
#    cat1_tn_delta_1  cat1_tn_lag_2  cat1_tn_delta_2  cat1_tn_lag_3  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat1_tn_delta_3  cat1_tn_lag_4  cat1_tn_delta_4  cat1_tn_lag_5  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat1_tn_delta_5  cat1_tn_lag_6  cat1_tn_delta_6  cat1_tn_lag_7  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat1_tn_delta_7  cat1_tn_lag_8  cat1_tn_delta_8  cat1_tn_lag_9  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat1_tn_delta_9  cat1_tn_lag_10  cat1_tn_delta_10  cat1_tn_lag_11  \
# 0              NaN             NaN               NaN             NaN
# 1              NaN             NaN               NaN             NaN
# 2              NaN             NaN               NaN             NaN
# 3              NaN             NaN               NaN             NaN
# 4              NaN             NaN               NaN             NaN
#
#    cat1_tn_delta_11  cat1_tn_lag_12  cat1_tn_delta_12  cat1_tn_lag_13  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat1_tn_delta_13  cat1_tn_lag_14  cat1_tn_delta_14  cat1_tn_lag_15  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat1_tn_delta_15  cat2_tn  cat2_tn_lag_1  cat2_tn_delta_1  cat2_tn_lag_2  \
# 0               NaN 11153.30            NaN              NaN            NaN
# 1               NaN 11153.30            NaN              NaN            NaN
# 2               NaN 11153.30            NaN              NaN            NaN
# 3               NaN 11153.30            NaN              NaN            NaN
# 4               NaN 11153.30            NaN              NaN            NaN
#
#    cat2_tn_delta_2  cat2_tn_lag_3  cat2_tn_delta_3  cat2_tn_lag_4  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat2_tn_delta_4  cat2_tn_lag_5  cat2_tn_delta_5  cat2_tn_lag_6  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat2_tn_delta_6  cat2_tn_lag_7  cat2_tn_delta_7  cat2_tn_lag_8  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat2_tn_delta_8  cat2_tn_lag_9  cat2_tn_delta_9  cat2_tn_lag_10  \
# 0              NaN            NaN              NaN             NaN
# 1              NaN            NaN              NaN             NaN
# 2              NaN            NaN              NaN             NaN
# 3              NaN            NaN              NaN             NaN
# 4              NaN            NaN              NaN             NaN
#
#    cat2_tn_delta_10  cat2_tn_lag_11  cat2_tn_delta_11  cat2_tn_lag_12  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat2_tn_delta_12  cat2_tn_lag_13  cat2_tn_delta_13  cat2_tn_lag_14  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat2_tn_delta_14  cat2_tn_lag_15  cat2_tn_delta_15  cat3_tn  cat3_tn_lag_1  \
# 0               NaN             NaN               NaN  3871.39            NaN
# 1               NaN             NaN               NaN  3871.39            NaN
# 2               NaN             NaN               NaN  3871.39            NaN
# 3               NaN             NaN               NaN  3871.39            NaN
# 4               NaN             NaN               NaN  3871.39            NaN
#
#    cat3_tn_delta_1  cat3_tn_lag_2  cat3_tn_delta_2  cat3_tn_lag_3  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat3_tn_delta_3  cat3_tn_lag_4  cat3_tn_delta_4  cat3_tn_lag_5  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat3_tn_delta_5  cat3_tn_lag_6  cat3_tn_delta_6  cat3_tn_lag_7  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat3_tn_delta_7  cat3_tn_lag_8  cat3_tn_delta_8  cat3_tn_lag_9  \
# 0              NaN            NaN              NaN            NaN
# 1              NaN            NaN              NaN            NaN
# 2              NaN            NaN              NaN            NaN
# 3              NaN            NaN              NaN            NaN
# 4              NaN            NaN              NaN            NaN
#
#    cat3_tn_delta_9  cat3_tn_lag_10  cat3_tn_delta_10  cat3_tn_lag_11  \
# 0              NaN             NaN               NaN             NaN
# 1              NaN             NaN               NaN             NaN
# 2              NaN             NaN               NaN             NaN
# 3              NaN             NaN               NaN             NaN
# 4              NaN             NaN               NaN             NaN
#
#    cat3_tn_delta_11  cat3_tn_lag_12  cat3_tn_delta_12  cat3_tn_lag_13  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat3_tn_delta_13  cat3_tn_lag_14  cat3_tn_delta_14  cat3_tn_lag_15  \
# 0               NaN             NaN               NaN             NaN
# 1               NaN             NaN               NaN             NaN
# 2               NaN             NaN               NaN             NaN
# 3               NaN             NaN               NaN             NaN
# 4               NaN             NaN               NaN             NaN
#
#    cat3_tn_delta_15
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
## Se verifica transformacion
df_test = df_sellout_transf[["product_id","periodo","tn","tn_mas_2","tn_lag_1","tn_delta_1"]].merge(df_prod_val1_val2,how="left",on="product_id")
df_test["tn"]=df_test.apply(lambda row: destransformar_valor(row["tn"],row["valor_1"],row["valor_2"]),axis=1)
df_test["tn_mas_2"]=df_test.apply(lambda row: destransformar_valor(row["tn_mas_2"],row["valor_1"],row["valor_2"]),axis=1)
df_test["tn_lag_1"]=df_test.apply(lambda row: destransformar_valor(row["tn_lag_1"],row["valor_1"],row["valor_2"]),axis=1)
df_test["tn_delta_1"]=df_test.apply(lambda row: destransformar_valor(row["tn_delta_1"],row["valor_1"],row["valor_2"]),axis=1)
df_test = df_test.merge(df_sellout[["product_id","periodo","tn","tn_mas_2","tn_lag_1","tn_delta_1"]],how="inner",on=["product_id","periodo"])
df_test[["product_id","periodo","tn_x","tn_y","tn_mas_2_x","tn_mas_2_y","tn_lag_1_x","tn_lag_1_y","tn_delta_1_x","tn_delta_1_y"]].head()
# Out:
#    product_id  periodo   tn_x   tn_y  tn_mas_2_x  tn_mas_2_y  tn_lag_1_x  \
# 0       20001   201701 934.77 934.77     1303.36     1303.36         NaN
# 1       20002   201701 550.16 550.16      834.74      834.74         NaN
# 2       20009   201701 378.08 378.08      456.07      456.07         NaN
# 3       20015   201701 304.25 304.25      462.48      462.48         NaN
# 4       20026   201701 184.40 184.40      259.71      259.71         NaN
#
#    tn_lag_1_y  tn_delta_1_x  tn_delta_1_y
# 0         NaN           NaN           NaN
# 1         NaN           NaN           NaN
# 2         NaN           NaN           NaN
# 3         NaN           NaN           NaN
# 4         NaN           NaN           NaN

# %%
# Compruebo que no haya diferencias
df_test["dif"]=df_test.tn_x-df_test.tn_y
df_test[df_test.dif>1e-3]
# Out:
#        product_id  periodo   tn_x  tn_mas_2_x  tn_lag_1_x  tn_delta_1_x  \
# 6150        20085   201811 204.56      204.56      204.56        204.56
# 6276        20712   201811  22.63       22.63       22.63         22.63
# 6388        21246   201811   0.54        0.54        0.54          0.54
# 6389        21256   201811   0.54        0.54        0.54          0.54
# 6390        21261   201811   0.54        0.54        0.54          0.54
# 6391        21262   201811   0.47        0.47        0.47          0.47
# 6442        20763   201811  11.53       11.53       11.53         11.53
# 6443        20836   201811  11.64       11.64       11.64         11.64
# 6476        20085   201812 204.56      204.56      204.56        204.56
# 6596        20408   201812  29.01       29.01       29.01         29.01
# 6602        20712   201812  22.63       22.63       22.63         22.63
# 6714        21246   201812   0.54        0.54        0.54          0.54
# 6715        21256   201812   0.54        0.54        0.54          0.54
# 6716        21261   201812   0.54        0.54        0.54          0.54
# 6717        21262   201812   0.47        0.47        0.47          0.47
# 6768        20763   201812  11.53       11.53       11.53         11.53
# 6769        20836   201812  11.64       11.64       11.64         11.64
# 6803        20085   201902 204.56      204.56      204.56        204.56
# 6845        21013   201902   2.00        2.00        2.00          2.00
# 6923        20408   201902  29.01       29.01       29.01         29.01
# 6929        20712   201902  22.63       22.63       22.63         22.63
# 7041        21246   201902   0.54        0.54        0.54          0.54
# 7042        21256   201902   0.54        0.54        0.54          0.54
# 7043        21261   201902   0.54        0.54        0.54          0.54
# 7044        21262   201902   0.47        0.47        0.47          0.47
# 7095        20763   201902  11.53       11.53       11.53         11.53
# 7096        20836   201902  11.64       11.64       11.64         11.64
# 20907       21244   201811   0.54        0.54        0.54          0.54
# 20908       21248   201811   0.46        0.46        0.46          0.46
# 20909       21259   201811   0.53        0.53        0.53          0.53
# 20910       21263   201811   0.53        0.53        0.53          0.53
# 21050       20700   201811   7.58        7.58        7.58          7.58
# 21062       21022   201811   1.64        1.64        1.64          1.64
# 21265       21201   201811   0.19        0.19        0.19          0.19
# 21382       21244   201812   0.54        0.54        0.54          0.54
# 21383       21248   201812   0.46        0.46        0.46          0.46
# 21384       21259   201812   0.53        0.53        0.53          0.53
# 21385       21263   201812   0.53        0.53        0.53          0.53
# 21525       20700   201812   7.58        7.58        7.58          7.58
# 21527       20990   201812   1.66        1.66        1.66          1.66
# 21528       21001   201812   1.32        1.32        1.32          1.32
# 21529       21037   201812   1.35        1.35        1.35          1.35
# 21537       21022   201812   1.64        1.64        1.64          1.64
# 21857       21244   201902   0.54        0.54        0.54          0.54
# 21858       21248   201902   0.46        0.46        0.46          0.46
# 21859       21259   201902   0.53        0.53        0.53          0.53
# 21860       21263   201902   0.53        0.53        0.53          0.53
# 22000       20700   201902   7.58        7.58        7.58          7.58
# 22002       20990   201902   1.66        1.66        1.66          1.66
# 22003       21001   201902   1.32        1.32        1.32          1.32
# 22004       21037   201902   1.35        1.35        1.35          1.35
# 22012       21022   201902   1.64        1.64        1.64          1.64
# 22152       20709   201902   5.40        5.40        5.40          5.40
# 22153       20917   201902   1.21        1.21        1.21          1.21
#
#        valor_2  valor_1   tn_y  tn_mas_2_y  tn_lag_1_y  tn_delta_1_y    dif
# 6150    204.56   204.56 148.08      202.92      204.56        -56.47  56.47
# 6276     22.63    22.63  10.93       10.17       22.63        -11.71  11.71
# 6388      0.54     0.54   0.35        0.04        0.54         -0.19   0.19
# 6389      0.54     0.54   0.36        0.04        0.54         -0.18   0.18
# 6390      0.54     0.54   0.34        0.04        0.54         -0.20   0.20
# 6391      0.47     0.47   0.37        0.03        0.47         -0.11   0.11
# 6442     11.53    11.53   9.63        7.63       11.53         -1.90   1.90
# 6443     11.64    11.64   8.33        6.22       11.64         -3.31   3.31
# 6476    204.56   204.56  91.49      163.81      148.08        -56.59 113.06
# 6596     29.01    29.01  17.65       25.51       40.20        -22.55  11.36
# 6602     22.63    22.63   7.04       13.66       10.93         -3.89  15.60
# 6714      0.54     0.54   0.06        0.06        0.35         -0.29   0.47
# 6715      0.54     0.54   0.06        0.05        0.36         -0.30   0.48
# 6716      0.54     0.54   0.06        0.05        0.34         -0.28   0.47
# 6717      0.47     0.47   0.09        0.06        0.37         -0.28   0.39
# 6768     11.53    11.53   5.19       11.18        9.63         -4.44   6.34
# 6769     11.64    11.64   5.85        8.25        8.33         -2.48   5.78
# 6803    204.56   204.56 163.81      138.39      202.92        -39.11  40.75
# 6845      2.00     2.00   1.64        1.14        1.78         -0.14   0.36
# 6923     29.01    29.01  25.51       18.46       22.91          2.59   3.50
# 6929     22.63    22.63  13.66        8.54       10.17          3.50   8.97
# 7041      0.54     0.54   0.06        0.02        0.04          0.02   0.48
# 7042      0.54     0.54   0.05        0.02        0.04          0.01   0.49
# 7043      0.54     0.54   0.05        0.03        0.04          0.01   0.49
# 7044      0.47     0.47   0.06        0.01        0.03          0.03   0.42
# 7095     11.53    11.53  11.18        5.18        7.63          3.55   0.35
# 7096     11.64    11.64   8.25        5.44        6.22          2.02   3.39
# 20907     0.54     0.54   0.35        0.05        0.54         -0.19   0.19
# 20908     0.46     0.46   0.36        0.03        0.46         -0.10   0.10
# 20909     0.53     0.53   0.39        0.04        0.53         -0.14   0.14
# 20910     0.53     0.53   0.39        0.04        0.53         -0.14   0.14
# 21050     7.58     7.58   5.97        2.40        7.58         -1.61   1.61
# 21062     1.64     1.64   1.50        1.35        1.64         -0.14   0.14
# 21265     0.19     0.19   0.14        0.31        0.19         -0.05   0.05
# 21382     0.54     0.54   0.06        0.06        0.35         -0.29   0.48
# 21383     0.46     0.46   0.10        0.06        0.36         -0.27   0.36
# 21384     0.53     0.53   0.06        0.05        0.39         -0.33   0.47
# 21385     0.53     0.53   0.06        0.06        0.39         -0.33   0.47
# 21525     7.58     7.58   2.77        3.44        5.97         -3.20   4.81
# 21527     1.66     1.66   0.91        0.97        1.92         -1.00   0.75
# 21528     1.32     1.32   0.71        0.66        1.36         -0.65   0.62
# 21529     1.35     1.35   0.77        0.55        1.44         -0.68   0.58
# 21537     1.64     1.64   1.45        1.26        1.50         -0.05   0.20
# 21857     0.54     0.54   0.06        0.02        0.05          0.01   0.48
# 21858     0.46     0.46   0.06        0.03        0.03          0.03   0.40
# 21859     0.53     0.53   0.05        0.02        0.04          0.01   0.48
# 21860     0.53     0.53   0.06        0.02        0.04          0.02   0.47
# 22000     7.58     7.58   3.44        0.56        2.40          1.04   4.14
# 22002     1.66     1.66   0.97        0.81        0.91          0.05   0.69
# 22003     1.32     1.32   0.66        0.51        0.75         -0.09   0.67
# 22004     1.35     1.35   0.55        0.56        0.61         -0.06   0.80
# 22012     1.64     1.64   1.26        0.77        1.35         -0.09   0.38
# 22152     5.40     5.40   4.87        5.22        5.10         -0.23   0.54
# 22153     1.21     1.21   1.06        2.23        1.97         -0.91   0.14

# %%
df_test[df_test.tn_x.isna()]
# Out:
# Empty DataFrame
# Columns: [product_id, periodo, tn_x, tn_mas_2_x, tn_lag_1_x, tn_delta_1_x, valor_2, valor_1, tn_y, tn_mas_2_y, tn_lag_1_y, tn_delta_1_y, dif]
# Index: []

# %%
#Transformo todas las categoricas
categories = ["plan_precios_cuidados","cat1","cat2","cat3","product_id"]

for c in categories: 
    df_sellout_transf[c] = df_sellout_transf[c].astype("category")   
    
#Elimino otras variables
df_sellout_transf = df_sellout_transf.drop(columns=["brand","periodo_fecha","imputado"])

# %%
df_train = df_sellout_transf[(df_sellout_transf.periodo <= train_periodo_limite) & (df_sellout_transf.periodo >= periodo_inicio)]
df_validate = df_sellout_transf[df_sellout_transf.periodo == validate_periodo]

df_train_all = df_sellout_transf[(df_sellout_transf.periodo <= train_all_periodo_limite) & (df_sellout_transf.periodo >= periodo_inicio)]
df_holdout = df_sellout_transf[df_sellout_transf.periodo == holdout_periodo]
# En validate y en test deben quedar 868 productos (son los productos a predecir)

#En validate dejamos unicamente los productos a predecir
print(len(df_validate))
df_validate = df_validate[df_validate.product_id.isin(df_prods_prediccion.product_id)]
df_validate = df_validate.sort_values(by="product_id",ascending=True)
print(len(df_validate))

#Idem holdout
print(len(df_holdout))
df_holdout = df_holdout[df_holdout.product_id.isin(df_prods_prediccion.product_id)]
df_holdout = df_holdout.sort_values(by="product_id",ascending=True)
print(len(df_holdout))

df_train.periodo.unique(),df_validate.periodo.unique(),df_train_all.periodo.unique(),df_holdout.periodo.unique()
# Out:
# 1051
# 868
# 1055
# 868
# (array([201701, 201702, 201703, 201704, 201705, 201706, 201707, 201708,
#         201709, 201710, 201711, 201712, 201801, 201802, 201803, 201804,
#         201805, 201806, 201807, 201808, 201809, 201810], dtype=int64),
#  array([201812], dtype=int64),
#  array([201701, 201702, 201703, 201704, 201705, 201706, 201707, 201708,
#         201709, 201710, 201711, 201712, 201801, 201802, 201803, 201804,
#         201805, 201806, 201807, 201808, 201809, 201810, 201811, 201812],
#        dtype=int64),
#  array([201902], dtype=int64))

# %%
# Train - Validate
X_train = df_train.drop(columns=["tn_mas_2","periodo"], axis=1)
X_validate = df_validate.drop(columns=["tn_mas_2","periodo"], axis=1)

y_train = df_train.tn_mas_2
y_validate = df_validate.tn_mas_2

# Train All - Holdout
X_train_all = df_train_all.drop(columns=["tn_mas_2","periodo"], axis=1)
X_holdout = df_holdout.drop(columns=["tn_mas_2","periodo"], axis=1)

y_train_all = df_train_all.tn_mas_2
y_holdout = df_holdout.tn_mas_2

print("X_train:", X_train.shape)
print("y_train:", y_train.shape)

print("\nX_validate:", X_validate.shape)
print("y_validate:", y_validate.shape)

print("\nX_train_all:", X_train_all.shape)
print("y_train_all:", y_train_all.shape)

print("\nX_holdout:", X_holdout.shape)
print("y_holdout:", y_holdout.shape)
# Out:
# X_train: (20016, 143)
# y_train: (20016,)
#
# X_validate: (868, 143)
# y_validate: (868,)
#
# X_train_all: (22118, 143)
# y_train_all: (22118,)
#
# X_holdout: (868, 143)
# y_holdout: (868,)

# %%
cols = X_train.columns.tolist()

# %%
def objective(trial):

    lgb_params = {
        'objective': 'regression', 
        'first_metric_only': True,
        'boost_from_average': True,
        'max_depth':-1,
        'lambda_l1': 0.0,
        'lambda_l2': 0.0,
        'min_gain_to_split':0.0,
        'force_row_wise':True,
        'feature_pre_filter':False,
        'metric': "None",
        'max_bin': MAX_BIN_PARAM,
        'learning_rate': trial.suggest_categorical('learning_rate', [0.01,0.05,0.1,0.2,0.5,0.9]),
        'num_leaves' : trial.suggest_int('num_leaves', 1, 1000),
        'feature_fraction': trial.suggest_categorical('feature_fraction', [0.3,0.4,0.5,0.6,0.7,0.8,0.9, 1.0]),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 1, 100),
        'bagging_freq':trial.suggest_int('bagging_freq', 1, 10),
        'bagging_fraction': trial.suggest_categorical('bagging_fraction',[0.7,0.75,0.8,0.85,0.9,0.95]),
        'extra_trees':trial.suggest_categorical('extra_trees',[True,False]),
        'verbose':-100,
        'num_threads':-1
    }
    
    lgb_params_num_boost_round = 10000  #un numero muy grande, lo limita early_stopping_rounds
    lgb_params_early_stopping_rounds = int(50 + 5/lgb_params['learning_rate']) #  #el parametro discolo, que depende de otro
    
    lgb_train = lgb.Dataset(data=X_train, label=y_train, feature_name=cols)
    lgb_validate = lgb.Dataset(data=X_validate, label=y_validate, reference=lgb_train, feature_name=cols)
    
    #Train using selected parameters
    model = lgb.train(lgb_params, lgb_train,
                  valid_sets=[lgb_validate],
                  num_boost_round=lgb_params_num_boost_round,
                  early_stopping_rounds=lgb_params_early_stopping_rounds,
                  feval=lgbm_error_rate,
                  verbose_eval=100)
    
    y_pred_validate =model.predict(X_validate) #Create predictions on test set
    er_validate = error_rate(y_validate,y_pred_validate)
    
    GLOBAL_PARAMS_ITER.append(lgb_params)
    GLOBAL_BEST_IT_ITER.append(model.best_iteration)
    GLOBAL_ER_VALIDATE_ITER.append(er_validate)
    GLOBAL_MODEL_ITER.append(model)
    
    return er_validate

# %%
#Antes de entrenar, se setea vector global para validate
GLOBAL_PRODUCT_IDS = actualizar_global_prods(y_validate_orig)

GLOBAL_PARAMS_ITER = []
GLOBAL_BEST_IT_ITER = []
GLOBAL_ER_VALIDATE_ITER = []
GLOBAL_MODEL_ITER = []

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=CANT_ITERACIONES_OPT_BAY)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2023-11-27 13:26:39,230] A new study created in memory with name: no-name-098e05a1-a0df-44a4-9d03-037860bfe15b
# Training until validation scores don't improve for 55 rounds
# [I 2023-11-27 13:26:49,235] Trial 0 finished with value: 29.39 and parameters: {'learning_rate': 0.9, 'num_leaves': 891, 'feature_fraction': 0.4, 'min_data_in_leaf': 14, 'bagging_freq': 2, 'bagging_fraction': 0.95, 'extra_trees': True}. Best is trial 0 with value: 29.39.
# Early stopping, best iteration is:
# [2]	valid_0's ER: 29.39
# Evaluated only: ER
# Training until validation scores don't improve for 75 rounds
# [100]	valid_0's ER: 23.04
# [I 2023-11-27 13:27:08,268] Trial 1 finished with value: 22.91 and parameters: {'learning_rate': 0.2, 'num_leaves': 174, 'feature_fraction': 0.8, 'min_data_in_leaf': 31, 'bagging_freq': 4, 'bagging_fraction': 0.95, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [74]	valid_0's ER: 22.91
# Evaluated only: ER
# Training until validation scores don't improve for 150 rounds
# [100]	valid_0's ER: 24.65
# [200]	valid_0's ER: 24.52
# [300]	valid_0's ER: 24.62
# Early stopping, best iteration is:
# [179]	valid_0's ER: 24.45
# Evaluated only: ER
# [I 2023-11-27 13:28:00,885] Trial 2 finished with value: 24.45 and parameters: {'learning_rate': 0.05, 'num_leaves': 765, 'feature_fraction': 0.9, 'min_data_in_leaf': 45, 'bagging_freq': 4, 'bagging_fraction': 0.8, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 75 rounds
# Early stopping, best iteration is:
# [9]	valid_0's ER: 24.72
# Evaluated only: ER
# [I 2023-11-27 13:28:21,581] Trial 3 finished with value: 24.72 and parameters: {'learning_rate': 0.2, 'num_leaves': 819, 'feature_fraction': 0.7, 'min_data_in_leaf': 39, 'bagging_freq': 2, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 60 rounds
# Early stopping, best iteration is:
# [2]	valid_0's ER: 25.82
# Evaluated only: ER
# [I 2023-11-27 13:28:35,034] Trial 4 finished with value: 25.82 and parameters: {'learning_rate': 0.5, 'num_leaves': 965, 'feature_fraction': 0.9, 'min_data_in_leaf': 51, 'bagging_freq': 3, 'bagging_fraction': 0.9, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 24.28
# Early stopping, best iteration is:
# [62]	valid_0's ER: 23.81
# Evaluated only: ER
# [I 2023-11-27 13:28:57,682] Trial 5 finished with value: 23.81 and parameters: {'learning_rate': 0.1, 'num_leaves': 671, 'feature_fraction': 0.8, 'min_data_in_leaf': 91, 'bagging_freq': 6, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 26.16
# Early stopping, best iteration is:
# [24]	valid_0's ER: 25.29
# Evaluated only: ER
# [I 2023-11-27 13:29:26,157] Trial 6 finished with value: 25.29 and parameters: {'learning_rate': 0.1, 'num_leaves': 707, 'feature_fraction': 0.4, 'min_data_in_leaf': 8, 'bagging_freq': 2, 'bagging_fraction': 0.85, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 550 rounds
# [100]	valid_0's ER: 27.79
# [200]	valid_0's ER: 25.61
# [300]	valid_0's ER: 25
# [400]	valid_0's ER: 24.7
# [500]	valid_0's ER: 24.45
# [600]	valid_0's ER: 24.47
# [700]	valid_0's ER: 24.55
# [800]	valid_0's ER: 24.57
# [900]	valid_0's ER: 24.58
# [1000]	valid_0's ER: 24.62
# Early stopping, best iteration is:
# [524]	valid_0's ER: 24.39
# Evaluated only: ER
# [I 2023-11-27 13:32:21,142] Trial 7 finished with value: 24.39 and parameters: {'learning_rate': 0.01, 'num_leaves': 162, 'feature_fraction': 1.0, 'min_data_in_leaf': 9, 'bagging_freq': 5, 'bagging_fraction': 0.7, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 55 rounds
# [I 2023-11-27 13:32:30,694] Trial 8 finished with value: 28.23 and parameters: {'learning_rate': 0.9, 'num_leaves': 393, 'feature_fraction': 0.8, 'min_data_in_leaf': 53, 'bagging_freq': 4, 'bagging_fraction': 0.9, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [6]	valid_0's ER: 28.23
# Evaluated only: ER
# Training until validation scores don't improve for 60 rounds
# [I 2023-11-27 13:32:35,727] Trial 9 finished with value: 24.59 and parameters: {'learning_rate': 0.5, 'num_leaves': 187, 'feature_fraction': 0.4, 'min_data_in_leaf': 87, 'bagging_freq': 2, 'bagging_fraction': 0.95, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [6]	valid_0's ER: 24.59
# Evaluated only: ER
# Training until validation scores don't improve for 75 rounds
# [100]	valid_0's ER: 25.52
# [I 2023-11-27 13:32:44,145] Trial 10 finished with value: 25.27 and parameters: {'learning_rate': 0.2, 'num_leaves': 37, 'feature_fraction': 0.5, 'min_data_in_leaf': 28, 'bagging_freq': 9, 'bagging_fraction': 0.75, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [76]	valid_0's ER: 25.27
# Evaluated only: ER
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 24.07
# Early stopping, best iteration is:
# [90]	valid_0's ER: 23.94
# Evaluated only: ER
# [I 2023-11-27 13:33:09,358] Trial 11 finished with value: 23.94 and parameters: {'learning_rate': 0.1, 'num_leaves': 555, 'feature_fraction': 0.8, 'min_data_in_leaf': 100, 'bagging_freq': 7, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 75 rounds
# [100]	valid_0's ER: 25.36
# [I 2023-11-27 13:33:34,084] Trial 12 finished with value: 25.09 and parameters: {'learning_rate': 0.2, 'num_leaves': 423, 'feature_fraction': 0.8, 'min_data_in_leaf': 75, 'bagging_freq': 7, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [85]	valid_0's ER: 25.09
# Evaluated only: ER
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 24.7
# [I 2023-11-27 13:33:48,113] Trial 13 finished with value: 24.01 and parameters: {'learning_rate': 0.1, 'num_leaves': 607, 'feature_fraction': 0.6, 'min_data_in_leaf': 69, 'bagging_freq': 7, 'bagging_fraction': 0.7, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [31]	valid_0's ER: 24.01
# Evaluated only: ER
# Training until validation scores don't improve for 550 rounds
# [100]	valid_0's ER: 27.97
# [200]	valid_0's ER: 25.37
# [300]	valid_0's ER: 24.18
# [400]	valid_0's ER: 24.08
# [500]	valid_0's ER: 23.97
# [600]	valid_0's ER: 24.02
# [700]	valid_0's ER: 24.1
# [800]	valid_0's ER: 24.09
# [900]	valid_0's ER: 24.13
# [1000]	valid_0's ER: 24.12
# Early stopping, best iteration is:
# [509]	valid_0's ER: 23.93
# Evaluated only: ER
# [I 2023-11-27 13:35:28,474] Trial 14 finished with value: 23.93 and parameters: {'learning_rate': 0.01, 'num_leaves': 329, 'feature_fraction': 0.3, 'min_data_in_leaf': 26, 'bagging_freq': 10, 'bagging_fraction': 0.85, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 150 rounds
# [100]	valid_0's ER: 24.91
# [200]	valid_0's ER: 24.37
# [I 2023-11-27 13:35:57,424] Trial 15 finished with value: 24.3 and parameters: {'learning_rate': 0.05, 'num_leaves': 267, 'feature_fraction': 0.8, 'min_data_in_leaf': 65, 'bagging_freq': 6, 'bagging_fraction': 0.8, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [52]	valid_0's ER: 24.3
# Evaluated only: ER
# Training until validation scores don't improve for 75 rounds
# [100]	valid_0's ER: 24.71
# [I 2023-11-27 13:36:08,776] Trial 16 finished with value: 24.17 and parameters: {'learning_rate': 0.2, 'num_leaves': 647, 'feature_fraction': 0.8, 'min_data_in_leaf': 98, 'bagging_freq': 5, 'bagging_fraction': 0.75, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [45]	valid_0's ER: 24.17
# Evaluated only: ER
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 24.72
# [200]	valid_0's ER: 24.14
# [300]	valid_0's ER: 24.17
# [I 2023-11-27 13:36:19,472] Trial 17 finished with value: 23.99 and parameters: {'learning_rate': 0.1, 'num_leaves': 3, 'feature_fraction': 1.0, 'min_data_in_leaf': 31, 'bagging_freq': 8, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [219]	valid_0's ER: 23.99
# Evaluated only: ER
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 23.8
# [I 2023-11-27 13:36:34,833] Trial 18 finished with value: 23.72 and parameters: {'learning_rate': 0.1, 'num_leaves': 424, 'feature_fraction': 0.5, 'min_data_in_leaf': 61, 'bagging_freq': 4, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [25]	valid_0's ER: 23.72
# Evaluated only: ER
# Training until validation scores don't improve for 75 rounds
# [I 2023-11-27 13:36:44,885] Trial 19 finished with value: 24.54 and parameters: {'learning_rate': 0.2, 'num_leaves': 472, 'feature_fraction': 0.5, 'min_data_in_leaf': 60, 'bagging_freq': 1, 'bagging_fraction': 0.95, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [22]	valid_0's ER: 24.54
# Evaluated only: ER
# Training until validation scores don't improve for 55 rounds
# [I 2023-11-27 13:36:50,921] Trial 20 finished with value: 27.49 and parameters: {'learning_rate': 0.9, 'num_leaves': 172, 'feature_fraction': 0.5, 'min_data_in_leaf': 19, 'bagging_freq': 4, 'bagging_fraction': 0.7, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [1]	valid_0's ER: 27.49
# Evaluated only: ER
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 24.49
# [200]	valid_0's ER: 24.83
# Early stopping, best iteration is:
# [102]	valid_0's ER: 24.41
# Evaluated only: ER
# [I 2023-11-27 13:37:18,721] Trial 21 finished with value: 24.41 and parameters: {'learning_rate': 0.1, 'num_leaves': 539, 'feature_fraction': 0.7, 'min_data_in_leaf': 80, 'bagging_freq': 6, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 24.45
# [200]	valid_0's ER: 24.17
# [300]	valid_0's ER: 24.03
# Early stopping, best iteration is:
# [283]	valid_0's ER: 23.99
# Evaluated only: ER
# [I 2023-11-27 13:37:45,895] Trial 22 finished with value: 23.99 and parameters: {'learning_rate': 0.1, 'num_leaves': 296, 'feature_fraction': 0.3, 'min_data_in_leaf': 89, 'bagging_freq': 5, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 24.38
# [200]	valid_0's ER: 24.26
# Early stopping, best iteration is:
# [134]	valid_0's ER: 24.18
# Evaluated only: ER
# [I 2023-11-27 13:38:35,570] Trial 23 finished with value: 24.18 and parameters: {'learning_rate': 0.1, 'num_leaves': 654, 'feature_fraction': 0.6, 'min_data_in_leaf': 39, 'bagging_freq': 3, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 23.73
# [200]	valid_0's ER: 22.99
# [I 2023-11-27 13:38:57,325] Trial 24 finished with value: 22.94 and parameters: {'learning_rate': 0.1, 'num_leaves': 86, 'feature_fraction': 0.5, 'min_data_in_leaf': 58, 'bagging_freq': 4, 'bagging_fraction': 0.95, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [185]	valid_0's ER: 22.94
# Evaluated only: ER
# Training until validation scores don't improve for 550 rounds
# [100]	valid_0's ER: 27.01
# [200]	valid_0's ER: 24.88
# [300]	valid_0's ER: 24.26
# [400]	valid_0's ER: 24
# [500]	valid_0's ER: 23.95
# [600]	valid_0's ER: 23.92
# [700]	valid_0's ER: 23.91
# [800]	valid_0's ER: 23.94
# [900]	valid_0's ER: 23.93
# [1000]	valid_0's ER: 23.88
# [1100]	valid_0's ER: 23.85
# [1200]	valid_0's ER: 23.89
# [1300]	valid_0's ER: 23.88
# [1400]	valid_0's ER: 23.87
# [1500]	valid_0's ER: 23.9
# [1600]	valid_0's ER: 23.9
# Early stopping, best iteration is:
# [1078]	valid_0's ER: 23.83
# Evaluated only: ER
# [I 2023-11-27 13:40:55,549] Trial 25 finished with value: 23.83 and parameters: {'learning_rate': 0.01, 'num_leaves': 80, 'feature_fraction': 0.5, 'min_data_in_leaf': 56, 'bagging_freq': 3, 'bagging_fraction': 0.8, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 60 rounds
# [I 2023-11-27 13:41:01,078] Trial 26 finished with value: 24.64 and parameters: {'learning_rate': 0.5, 'num_leaves': 94, 'feature_fraction': 0.5, 'min_data_in_leaf': 37, 'bagging_freq': 4, 'bagging_fraction': 0.9, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [3]	valid_0's ER: 24.64
# Evaluated only: ER
# Training until validation scores don't improve for 150 rounds
# [100]	valid_0's ER: 24.47
# [200]	valid_0's ER: 24.05
# [300]	valid_0's ER: 24.1
# Early stopping, best iteration is:
# [206]	valid_0's ER: 23.94
# Evaluated only: ER
# [I 2023-11-27 13:41:46,663] Trial 27 finished with value: 23.94 and parameters: {'learning_rate': 0.05, 'num_leaves': 233, 'feature_fraction': 0.5, 'min_data_in_leaf': 45, 'bagging_freq': 3, 'bagging_fraction': 0.75, 'extra_trees': False}. Best is trial 1 with value: 22.91.
# Training until validation scores don't improve for 75 rounds
# [I 2023-11-27 13:41:55,738] Trial 28 finished with value: 25.36 and parameters: {'learning_rate': 0.2, 'num_leaves': 359, 'feature_fraction': 0.5, 'min_data_in_leaf': 65, 'bagging_freq': 1, 'bagging_fraction': 0.85, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [20]	valid_0's ER: 25.36
# Evaluated only: ER
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's ER: 23.56
# [200]	valid_0's ER: 23.49
# [I 2023-11-27 13:42:17,000] Trial 29 finished with value: 23.37 and parameters: {'learning_rate': 0.1, 'num_leaves': 102, 'feature_fraction': 0.5, 'min_data_in_leaf': 22, 'bagging_freq': 5, 'bagging_fraction': 0.95, 'extra_trees': True}. Best is trial 1 with value: 22.91.
# Early stopping, best iteration is:
# [183]	valid_0's ER: 23.37
# Evaluated only: ER
# Number of finished trials: 30
# Best trial: {'learning_rate': 0.2, 'num_leaves': 174, 'feature_fraction': 0.8, 'min_data_in_leaf': 31, 'bagging_freq': 4, 'bagging_fraction': 0.95, 'extra_trees': True}

# %%
best_model_index = study.best_trial.number

# %%
best_model = GLOBAL_MODEL_ITER[best_model_index]

# %%
plot_lgb_importances(best_model, num=30, plot=True)
# Out:
#                       feature  split  gain
# 1                          tn    225 15.88
# 20                   tn_lag_1    385  6.15
# 3            cust_request_qty     97  2.97
# 5                         mes     41  2.52
# 8                        cat2    235  2.45
# ..                        ...    ...   ...
# 16  promedio_mens_dolar_venta     14  0.09
# 4       plan_precios_cuidados     19  0.08
# 50                    cat1_tn     14  0.05
# 11          producto_estrella     10  0.04
# 17                 catastrofe      0  0.00
#
# [143 rows x 3 columns]

# %%
lgbtrain_all = lgb.Dataset(data=X_train_all, label=y_train_all, feature_name=cols)

# %% [markdown]
# ## Modelo Final

# %%
final_model = lgb.train(GLOBAL_PARAMS_ITER[best_model_index], lgbtrain_all, num_boost_round=GLOBAL_BEST_IT_ITER[best_model_index])

# %%
GLOBAL_PRODUCT_IDS = actualizar_global_prods(y_holdout_orig)

y_pred_holdout = final_model.predict(X_holdout)
er_holdout = error_rate(y_holdout,y_pred_holdout)
er_holdout
# Out:
# 27.23

# %%
print(X_holdout.shape)
df_prediccion = X_holdout.copy()
df_prediccion["tn_target"]=np.array(y_holdout_orig)
df_prediccion["tn_predicted"]=np.array(destransformar_vector(y_pred_holdout))
print(df_prediccion.shape)
# Out:
# (868, 143)
# (868, 145)

# %%
print("Toneladas Holdout:\t", df_prediccion.tn_target.sum())
print("Toneladas Prediccion:\t", df_prediccion.tn_predicted.sum())
# Out:
# Toneladas Holdout:	 33763.86541
# Toneladas Prediccion:	 32582.420122053165

# %%
df_prediccion = df_prediccion.sort_values(by="product_id",ascending=True)
df_prediccion.to_csv(arch_predicciones_full, index=False)
df_prediccion[["product_id","tn_predicted"]].to_csv(arch_predicciones_simple, index=False)

# %%
print("Error Rate Validate:",GLOBAL_ER_VALIDATE_ITER[best_model_index])
print("Error Rate Holdout:",er_holdout)
# Out:
# Error Rate Validate: 22.91
# Error Rate Holdout: 27.23

# %%
# Armo resultados y calculo modelo final y semillerio para top 5 de error de validacion
df_resultado = pd.DataFrame(data={"error_rate_validation":GLOBAL_ER_VALIDATE_ITER,
                                  "best_iteration": GLOBAL_BEST_IT_ITER,
                                  "params":GLOBAL_PARAMS_ITER})
df_resultado["max_bin"]=MAX_BIN_PARAM

df_resultado = df_resultado.sort_values(by="error_rate_validation",ascending=True)

er_holdout_iter = [None] * len(df_resultado)
er_holdout_semillerio_iter = [None] * len(df_resultado)
for i in range(0,5):
    print("Iteración:",i)
    #Modelo Final (Sin Semillerio)
    final_model = lgb.train(df_resultado.iloc[i].params, lgbtrain_all, num_boost_round=df_resultado.iloc[i].best_iteration)
    y_pred_holdout = final_model.predict(X_holdout)
    er_holdout = error_rate(y_holdout,y_pred_holdout)
    er_holdout_iter[i]=er_holdout
    
    #Semillerio
    er_holdout_semillerio_iter[i]=(semillerio(lgbtrain_all, df_resultado.iloc[i].params, df_resultado.iloc[i].best_iteration, X_holdout, y_holdout))

df_resultado["error_rate_holdout"]=er_holdout_iter    
df_resultado["error_rate_holdout_semillerio"]=er_holdout_semillerio_iter    
    
datetime_string = datetime.datetime.now().strftime('%Y-%m-%d_%H.%M')
df_resultado.to_excel("resultados_opt_bay_"+GLOBAL_TRANSF+"_"+str(CANT_ITERACIONES_OPT_BAY)+"_"+datetime_string+".xlsx",index=False)
# Out:
# Iteración: 0
# Iteración: 1
# Iteración: 2
# Iteración: 3
# Iteración: 4

# %%
df_resultado
# Out:
#     error_rate_validation  best_iteration  \
# 1                   22.91              74
# 24                  22.94             185
# 29                  23.37             183
# 18                  23.72              25
# 5                   23.81              62
# 25                  23.83            1078
# 14                  23.93             509
# 27                  23.94             206
# 11                  23.94              90
# 22                  23.99             283
# 17                  23.99             219
# 13                  24.01              31
# 16                  24.17              45
# 23                  24.18             134
# 15                  24.30              52
# 7                   24.39             524
# 21                  24.41             102
# 2                   24.45             179
# 19                  24.54              22
# 9                   24.59               6
# 26                  24.64               3
# 3                   24.72               9
# 12                  25.09              85
# 10                  25.27              76
# 6                   25.29              24
# 28                  25.36              20
# 4                   25.82               2
# 20                  27.49               1
# 8                   28.23               6
# 0                   29.39               2
#
#                                                params  max_bin  \
# 1   {'objective': 'regression', 'first_metric_only...     1023
# 24  {'objective': 'regression', 'first_metric_only...     1023
# 29  {'objective': 'regression', 'first_metric_only...     1023
# 18  {'objective': 'regression', 'first_metric_only...     1023
# 5   {'objective': 'regression', 'first_metric_only...     1023
# 25  {'objective': 'regression', 'first_metric_only...     1023
# 14  {'objective': 'regression', 'first_metric_only...     1023
# 27  {'objective': 'regression', 'first_metric_only...     1023
# 11  {'objective': 'regression', 'first_metric_only...     1023
# 22  {'objective': 'regression', 'first_metric_only...     1023
# 17  {'objective': 'regression', 'first_metric_only...     1023
# 13  {'objective': 'regression', 'first_metric_only...     1023
# 16  {'objective': 'regression', 'first_metric_only...     1023
# 23  {'objective': 'regression', 'first_metric_only...     1023
# 15  {'objective': 'regression', 'first_metric_only...     1023
# 7   {'objective': 'regression', 'first_metric_only...     1023
# 21  {'objective': 'regression', 'first_metric_only...     1023
# 2   {'objective': 'regression', 'first_metric_only...     1023
# 19  {'objective': 'regression', 'first_metric_only...     1023
# 9   {'objective': 'regression', 'first_metric_only...     1023
# 26  {'objective': 'regression', 'first_metric_only...     1023
# 3   {'objective': 'regression', 'first_metric_only...     1023
# 12  {'objective': 'regression', 'first_metric_only...     1023
# 10  {'objective': 'regression', 'first_metric_only...     1023
# 6   {'objective': 'regression', 'first_metric_only...     1023
# 28  {'objective': 'regression', 'first_metric_only...     1023
# 4   {'objective': 'regression', 'first_metric_only...     1023
# 20  {'objective': 'regression', 'first_metric_only...     1023
# 8   {'objective': 'regression', 'first_metric_only...     1023
# 0   {'objective': 'regression', 'first_metric_only...     1023
#
#     error_rate_holdout  error_rate_holdout_semillerio
# 1                27.23                          25.36
# 24               26.08                          25.64
# 29               26.54                          25.57
# 18               26.78                          26.87
# 5                25.80                          25.71
# 25                 NaN                            NaN
# 14                 NaN                            NaN
# 27                 NaN                            NaN
# 11                 NaN                            NaN
# 22                 NaN                            NaN
# 17                 NaN                            NaN
# 13                 NaN                            NaN
# 16                 NaN                            NaN
# 23                 NaN                            NaN
# 15                 NaN                            NaN
# 7                  NaN                            NaN
# 21                 NaN                            NaN
# 2                  NaN                            NaN
# 19                 NaN                            NaN
# 9                  NaN                            NaN
# 26                 NaN                            NaN
# 3                  NaN                            NaN
# 12                 NaN                            NaN
# 10                 NaN                            NaN
# 6                  NaN                            NaN
# 28                 NaN                            NaN
# 4                  NaN                            NaN
# 20                 NaN                            NaN
# 8                  NaN                            NaN
# 0                  NaN                            NaN

# %%
duration = 500  # 1000 milliseconds = 1 second
winsound.Beep(2000, duration)
